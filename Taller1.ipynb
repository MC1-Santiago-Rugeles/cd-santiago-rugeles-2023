# %% [markdown]
# <a href="https://colab.research.google.com/github/Rugeles13/cd-santiago-rugeles-2023/blob/main/Taller1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
area = [76,92,107,42,65,150,65,105,40,55]
valor = [200,320,300,160,190,315,230,380,155,175]

# %%
model = LinearRegression()

X = pd.DataFrame(area)
y = pd.Series(valor)

model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Variable Independiente')
plt.ylabel('Variable Dependiente')
plt.title('Regresión Lineal')
plt.show()

# %%
m = model.coef_[0]
b = model.intercept_


ecuacion_recta = f"y = {m:.2f}x + {b:.2f}"
print(ecuacion_recta)
# Out:
# y = 1.94x + 87.65
